# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Linear Regression Model for the Salary_Data dataset

# %%
import pandas as pd
salary=pd.read_csv('drive/My Drive/Colab Notebooks/Salary_Data.csv')

# %%
salary
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x=salary.iloc[:,0].values

# %%
x
# Out:
# array([ 1.1,  1.3,  1.5,  2. ,  2.2,  2.9,  3. ,  3.2,  3.2,  3.7,  3.9,
#         4. ,  4. ,  4.1,  4.5,  4.9,  5.1,  5.3,  5.9,  6. ,  6.8,  7.1,
#         7.9,  8.2,  8.7,  9. ,  9.5,  9.6, 10.3, 10.5])

# %%
y=salary.iloc[:,1].values

# %%
y
# Out:
# array([ 39343.,  46205.,  37731.,  43525.,  39891.,  56642.,  60150.,
#         54445.,  64445.,  57189.,  63218.,  55794.,  56957.,  57081.,
#         61111.,  67938.,  66029.,  83088.,  81363.,  93940.,  91738.,
#         98273., 101302., 113812., 109431., 105582., 116969., 112635.,
#        122391., 121872.])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)
x_train=x_train.reshape(-1,1)
x_test=x_test.reshape(-1,1)

# %%
#Standard scalar
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test=st.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([ 40748.96184072, 122699.62295594,  64961.65717022,  63099.14214487,
#        115249.56285456, 107799.50275317])

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='green')
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Experience(Training)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Linear Regression Model for Social_Networking Ads

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='green')
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,regressor.predict(x_test),color='blue')
plt.title('Salary vs Experience(Testing)')
plt.xlabel('Years of experience')
plt.ylabel('Salary')
plt.show()

# %%
import pandas as pd
social=pd.read_csv('drive/My Drive/Colab Notebooks/Social_Network_Ads.csv')

# %%
social
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
x=social.iloc[:,[2]].values

# %%
x
# Out:
# array([[19],
#        [35],
#        [26],
#        [27],
#        [19],
#        [27],
#        [27],
#        [32],
#        [25],
#        [35],
#        [26],
#        [26],
#        [20],
#        [32],
#        [18],
#        [29],
#        [47],
#        [45],
#        [46],
#        [48],
#        [45],
#        [47],
#        [48],
#        [45],
#        [46],
#        [47],
#        [49],
#        [47],
#        [29],
#        [31],
#        [31],
#        [27],
#        [21],
#        [28],
#        [27],
#        [35],
#        [33],
#        [30],
#        [26],
#        [27],
#        [27],
#        [33],
#        [35],
#        [30],
#        [28],
#        [23],
#        [25],
#        [27],
#        [30],
#        [31],
#        [24],
#        [18],
#        [29],
#        [35],
#        [27],
#        [24],
#        [23],
#        [28],
#        [22],
#        [32],
#        [27],
#        [25],
#        [23],
#        [32],
#        [59],
#        [24],
# ...

# %%
y=social.iloc[:,[3]].values

# %%
y
# Out:
# array([[ 19000],
#        [ 20000],
#        [ 43000],
#        [ 57000],
#        [ 76000],
#        [ 58000],
#        [ 84000],
#        [150000],
#        [ 33000],
#        [ 65000],
#        [ 80000],
#        [ 52000],
#        [ 86000],
#        [ 18000],
#        [ 82000],
#        [ 80000],
#        [ 25000],
#        [ 26000],
#        [ 28000],
#        [ 29000],
#        [ 22000],
#        [ 49000],
#        [ 41000],
#        [ 22000],
#        [ 23000],
#        [ 20000],
#        [ 28000],
#        [ 30000],
#        [ 43000],
#        [ 18000],
#        [ 74000],
#        [137000],
#        [ 16000],
#        [ 44000],
#        [ 90000],
#        [ 27000],
#        [ 28000],
#        [ 49000],
#        [ 72000],
#        [ 31000],
#        [ 17000],
#        [ 51000],
#        [108000],
#        [ 15000],
#        [ 84000],
#        [ 20000],
#        [ 79000],
#        [ 54000],
#        [135000],
#        [ 89000],
#        [ 32000],
#        [ 44000],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Standard scalar
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x_train=st.fit_transform(x_train)
x_test=st.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regressor.predict(x_test)

# %%
y_pred
# Out:
# array([[65581.69999059],
#        [69812.44068416],
#        [68225.91292407],
#        [65581.69999059],
#        [68225.91292407],
#        [63995.1722305 ],
#        [66110.54257728],
#        [68754.75551077],
#        [59235.58895023],
#        [74572.02396443],
#        [65581.69999059],
#        [64524.01481719],
#        [69283.59809746],
#        [70341.28327086],
#        [60293.27412362],
#        [66639.38516398],
#        [69283.59809746],
#        [59764.43153692],
#        [78802.764658  ],
#        [68225.91292407],
#        [68225.91292407],
#        [74572.02396443],
#        [71398.96844425],
#        [74572.02396443],
#        [61879.80188371],
#        [75629.70913782],
#        [64524.01481719],
#        [65052.85740389],
#        [69283.59809746],
#        [66639.38516398],
#        [60822.11671032],
#        [69283.59809746],
#        [79860.4498314 ],
#        [69283.59809746],
#        [62408.64447041],
#        [59235.58895023],
#        [61350.95929701],
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train,y_train,color='green')
plt.scatter(x_test,y_test,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.title('Salary vs Age(Training)')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(x_test,y_test,color='green')
plt.scatter(x_train,y_train,color='red')
plt.plot(x_test,regressor.predict(x_test),color='blue')
plt.title('Salary vs Age(Testing)')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.show()

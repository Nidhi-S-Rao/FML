# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import AdaBoostClassifier
from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
mushroom=pd.read_csv('drive/My Drive/Colab Notebooks/mushrooms.csv')

# %%
mushroom
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0               c         n          k  ...                        s
# 1               c         b          k  ...                        s
# 2               c         b          n  ...                        s
# 3               c         n          n  ...                        s
# 4               w         b          k  ...                        s
# ...           ...       ...        ...  ...                      ...
# 8119            c         b          y  ...                        s
# 8120            c         b          y  ...                        s
# 8121            c         b          n  ...                        s
# 8122            c         n          b  ...                        k
# 8123            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                         w                      w         p          w
# 1                         w                      w         p          w
# 2                         w                      w         p          w
# 3                         w                      w         p          w
# 4                         w                      w         p          w
# ...                     ...                    ...       ...        ...
# 8119                      o                      o         p          o
# 8120                      o                      o         p          n
# 8121                      o                      o         p          o
# 8122                      w                      w         p          w
# 8123                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 0              o         p                 k          s       u
# 1              o         p                 n          n       g
# 2              o         p                 n          n       m
# 3              o         p                 k          s       u
# 4              o         e                 n          a       g
# ...          ...       ...               ...        ...     ...
# 8119           o         p                 b          c       l
# 8120           o         p                 b          v       l
# 8121           o         p                 b          c       l
# 8122           o         e                 w          v       l
# 8123           o         p                 o          c       l
#
# [8124 rows x 23 columns]

# %%
dataset = mushroom.sample(frac = 1)
dataset.colums = ['class', 'cap-shape',	'cap-surface',	'cap-color',	'bruises',	'odor',	'gill-attachment',	'gill-spacing',	'gill-size',	'gill-color']
dataset
# Out:
# <ipython-input-6-a8db9cde4a4f>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataset.colums = ['class', 'cap-shape',	'cap-surface',	'cap-color',	'bruises',	'odor',	'gill-attachment',	'gill-spacing',	'gill-size',	'gill-color']
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 288      e         x           y         n       t    l               f
# 549      e         x           s         y       t    a               f
# 5931     p         x           y         n       f    y               f
# 1626     e         x           f         n       f    n               f
# 4823     p         x           f         y       f    f               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 1422     e         x           f         n       t    n               f
# 1909     e         f           s         w       f    n               f
# 8048     p         k           s         n       f    y               f
# 4969     p         x           y         y       f    f               f
# 7205     e         k           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 288             c         b          n  ...                        y
# 549             c         b          g  ...                        s
# 5931            c         n          b  ...                        s
# 1626            w         b          h  ...                        s
# 4823            c         b          h  ...                        k
# ...           ...       ...        ...  ...                      ...
# 1422            c         b          n  ...                        s
# 1909            w         b          n  ...                        f
# 8048            c         n          b  ...                        k
# 4969            c         b          h  ...                        k
# 7205            c         b          y  ...                        s
#
#      stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 288                       w                      w         p          w
# 549                       w                      w         p          w
# 5931                      p                      w         p          w
# 1626                      w                      w         p          w
# 4823                      n                      p         p          w
# ...                     ...                    ...       ...        ...
# 1422                      g                      p         p          w
# 1909                      w                      w         p          w
# 8048                      w                      p         p          w
# 4969                      b                      b         p          w
# 7205                      o                      o         p          o
#
#      ring-number ring-type spore-print-color population habitat
# 288            o         p                 n          y       p
# 549            o         p                 n          n       m
# 5931           o         e                 w          v       p
# 1626           o         e                 n          s       g
# 4823           o         l                 h          y       g
# ...          ...       ...               ...        ...     ...
# 1422           o         p                 n          v       d
# 1909           o         e                 n          s       g
# 8048           o         e                 w          v       d
# 4969           o         l                 h          v       p
# 7205           o         p                 y          c       l
#
# [8124 rows x 23 columns]

# %%
# Label Encoding
label_encoders = {}
for label in dataset.columns:
    label_encoders[label] = LabelEncoder()
    dataset[label] = label_encoders[label].fit_transform(dataset[label])

# %%
#split dataset in features and target variable
X = dataset.drop(['class'],axis = 1)
y = dataset['class']

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X,y, test_size=0.3 , random_state = 1)

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=400, learning_rate=1)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
prediction = metrics.accuracy_score(y_test, y_pred)

# %%
print("Accuracy:",prediction*100, '%')
# Out:
# Accuracy: 100.0 %

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=400, learning_rate=0.5)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
print("Accuracy:",prediction*100, '%')
# Out:
# Accuracy: 100.0 %

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=400, learning_rate=0.3)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
print("Accuracy:",prediction*100, '%')
# Out:
# Accuracy: 100.0 %

# %%
model = DecisionTreeClassifier(criterion='entropy', max_depth=2)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=400, learning_rate=0.3)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
print("Accuracy:",prediction*100, '%')
# Out:
# Accuracy: 100.0 %

# %%
model = DecisionTreeClassifier(criterion='gini', max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=400, learning_rate=0.3)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
print("Accuracy:",prediction*100, '%')
# Out:
# Accuracy: 100.0 %

# %%
model = DecisionTreeClassifier(criterion='gini', max_depth=1)
AdaBoost = AdaBoostClassifier(base_estimator=model, n_estimators=100, learning_rate=0.3)
boostmodel = AdaBoost.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(

# %%
y_pred = boostmodel.predict(X_test)

# %%
print("Accuracy:",prediction*100, '%')
# Out:
# Accuracy: 100.0 %
